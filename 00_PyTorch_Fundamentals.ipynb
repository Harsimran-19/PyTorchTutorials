# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1+cu116'

# %% [markdown]
# # Intro To Tensors

# %%
scalar=torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
sc2=torch.tensor(7)
out=scalar*sc2

# %%
print(out.item())
print(out.ndim)
print(out.shape)
# Out:
# 49
# 0
# torch.Size([])

# %%
vector=torch.tensor([-1,1,1,2,3,3])

# %%
# print(vector.item())
print(vector.ndim)
print(vector.shape)
# Out:
# 1
# torch.Size([6])

# %%
matrix=torch.tensor([[13,4,4],[1,2,3]])

# %%
# print(vector.item())
print(matrix.ndim)
print(matrix.shape)
# Out:
# 2
# torch.Size([2, 3])

# %%
random_tensor=torch.rand(size=[3,4])

# %%
random_image_size_tensor = torch.rand(size=(28, 28, 3))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(random_image_size_tensor.data)

# %%
zeros = torch.zeros(size=(3, 4))

# %%
ones = torch.ones(size=(3, 4))
